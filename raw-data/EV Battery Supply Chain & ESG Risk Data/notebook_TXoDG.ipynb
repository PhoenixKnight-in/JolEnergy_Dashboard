# %% [markdown]
# Create a comprehensive dataset for Supply-Chain Footprint for EV Battery Materials with the following requirements:
#
# 1. Generate realistic but representative data based on the research I've gathered from IRENA, IEA, SLR Consulting, USGS sources for 2023-2024
# 2. Include these columns: material_type, origin_country, export_volume_mt, smelter_operator, processing_location, timestamp, esg_risk_score
# 3. Cover the key materials: lithium, cobalt, nickel, graphite, copper, phosphorous, manganese
# 4. Use the data points from my research including:
#    - Australia, Chile, China for lithium (>90% of production, 0.96 Mt total)
#    - DRC for cobalt (>74% of mining, 0.22 Mt total)
#    - Indonesia, Philippines for nickel (~60% of mining, 3.6 Mt total)
#    - China for graphite (~75%, 1.6 Mt natural + 2.4 Mt synthetic)
# 5. Calculate ESG risk scores based on country governance, environmental, and social factors
# 6. Include major smelters and processing locations
# 7. Use timestamps from 2023-2024 data
# 8. Export as CSV named "output.csv"
# 9. Create metadata summary explaining sources, methodology, and data quality
#
# Focus on creating a realistic, well-structured dataset that meets the user's criteria for supply chain transparency and ESG analysis.
